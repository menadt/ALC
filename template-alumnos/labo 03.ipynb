# %%
import matplotlib.pyplot as plt
import numpy as np
from main import proyectarPts, vistform, pointsGrid

# %%
T=np.array([[2,0],[0,3]])
wz=np.array([[2],[3]])
Tinv=np.array([[1/2,0],[0,1/3]])
corners = np.array([[0,0],[100,100]])
wz = pointsGrid(corners)
vistform(T, wz, 'Deformar coordenadas')
# Out:
# [[1.]
#  [1.]]

# %%
T = np.array([[1., 0.4],[0,1.]])
corners = np.array([[0,0],[100,100]])
wz = pointsGrid(corners)
Tinv=np.array([[1., -0.4],[0,1.]])
xy=np.array([[3.8],[2]])
print(proyectarPts(Tinv,xy))
vistform(Tinv, wz, 'Deformar coordenadas')
# Out:
# [[3.]
#  [2.]]
